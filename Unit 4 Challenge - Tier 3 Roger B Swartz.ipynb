# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd


# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

#Install pip
# !pip install openpyxl

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#Transpose Function
properties = properties.transpose()

properties.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
#print(properties.shape)
properties.head(357)

#Check for Nan Values in the dataframe
#properties.isna().any()

#Sum NaN vlaues for each column
#properties.isna().sum()
#properties.isna().sum(axis=0)

#Sum NaN values for each row
#properties.isna().sum(axis=1)

Delete the columns by their column index name as shown below
properties.drop(["Unnamed: 34", "Unnamed: 47", "Unnamed: 37"], inplace=True)

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#convert row 0 to the column headers or column index
properties.columns = properties.iloc[0]
# Out:
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.12/site-packages/pandas/core/indexes/base.py:7631: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(index_like, name=name, copy=copy)

# %%
#Convert the present row indexs to an index of 0, 1, 2, 3, etc.
#properties.reset_index()

#Convert the present column indexs to an index of 0, 1, 2, 3, etc.
#properties.reset_index(axis=1)

#properties.drop(columns= ["index"], inplace=True)

#properties.drop("Unnamed: 0", axis=1, errors='ignore')

#Remove row 0 which is the row that contained the time stamps and was converted to column headers / column index
properties.drop(["Unnamed: 0"], inplace=True)
properties.head()
# Out:
# Unnamed: 0                NaT   1995-01-01   1995-02-01   1995-03-01  \
# City of London      E09000001  91448.98487  82202.77314  79120.70256
# Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# Barnet              E09000003  93284.51832  93190.16963  92247.52435
# Bexley              E09000004  64958.09036  64787.92069  64367.49344
# Brent               E09000005  71306.56698  72022.26197  72015.76274
#
# Unnamed: 0           1995-04-01   1995-05-01   1995-06-01   1995-07-01  \
# City of London      77101.20804  84409.14932  94900.51244  110128.0423
# Barking & Dagenham  53133.50526  53042.24852  53700.34831  52113.12157
# Barnet              90762.87492  90258.00033  90107.23471  91441.24768
# Bexley              64277.66881  63997.13588  64252.32335  63722.70055
# Brent               72965.63094  73704.04743  74310.48167  74127.03788
#
# Unnamed: 0           1995-08-01   1995-09-01  ... 2023-11-01 2023-12-01  \
# ...

# %%
properties.head()
#properties.drop(columns= ["index"], inplace=True)
#properties.drop(columns= ["Index: 0"], inplace=True)
# Out:
# Unnamed: 0                NaT   1995-01-01   1995-02-01   1995-03-01  \
# City of London      E09000001  91448.98487  82202.77314  79120.70256
# Barking & Dagenham  E09000002   50460.2266  51085.77983  51268.96956
# Barnet              E09000003  93284.51832  93190.16963  92247.52435
# Bexley              E09000004  64958.09036  64787.92069  64367.49344
# Brent               E09000005  71306.56698  72022.26197  72015.76274
#
# Unnamed: 0           1995-04-01   1995-05-01   1995-06-01   1995-07-01  \
# City of London      77101.20804  84409.14932  94900.51244  110128.0423
# Barking & Dagenham  53133.50526  53042.24852  53700.34831  52113.12157
# Barnet              90762.87492  90258.00033  90107.23471  91441.24768
# Bexley              64277.66881  63997.13588  64252.32335  63722.70055
# Brent               72965.63094  73704.04743  74310.48167  74127.03788
#
# Unnamed: 0           1995-08-01   1995-09-01  ... 2023-11-01 2023-12-01  \
# ...

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#Line plot of monthly price 
#properties.plot(x = "Unnamed: 0", y = "City of London")
#plt.show()
#row_1 = properties.loc[1]
#print(row_1)
#print(properties.columns)

# x_values are the column headers / column index selecting the last 240 column headers
x_values = properties.columns[-240:]

# y_values selected are the 5th row and the last 240 values or last 20 years
y_values = properties.iloc[4][-240:]

#x_value_for_regressions = np.arange(1, len(x_values) + 1)
#regression_line = slope*x_value_for_regressions + intercept
#slope = np.polyfit(x_value_for_regressions, y_values, 1)

plt.plot(x_values, y_values)
plt.xlabel("Month and Year")
plt.ylabel("Price in Pounds")
plt.title("Line Plot of Monthly Price for Brent Borough")
           
#plt.plot(x_values, regression_line, color='red')

plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#In this first example I took the ratio of current house prices to prices 20 years ago by selecting the specific month
#Ratio of Current House Prices to Prices 20 years ago 

# Ration of current house prices to prices 20 years ago
properties['20_year_price_ratios'] = properties.iloc[0:, 356] / properties.iloc[0:, 116]

#Convert 20 year price ratios to numeric 
properties['20_year_price_ratios'] = pd.to_numeric(properties['20_year_price_ratios'], errors='coerce')

#Round to 2 decimal places
properties['20_year_price_ratios_rounded'] = properties['20_year_price_ratios'].round(2)

#properties['20_year_price_ratios_rounded'] = pd.to_numeric(properties['20_year_price_ratios_rounded'], errors='coerce')

#Sort in descending order
properties_sorted = properties.sort_values(by='20_year_price_ratios_rounded', ascending=False)

#Select and print the last column
town_price_ratios = properties_sorted.iloc[: , [-1]]

print(town_price_ratios)
# Out:
# Unnamed: 0            20_year_price_ratios_rounded
# Hackney                                       2.61
# Westminster                                   2.54
# Waltham Forest                                2.53
# Lewisham                                      2.48
# City of London                                2.47
# Greenwich                                     2.41
# Haringey                                      2.40
# Merton                                        2.36
# Inner London                                  2.32
# Lambeth                                       2.32
# Islington                                     2.31
# Southwark                                     2.27
# LONDON                                        2.26
# Richmond upon Thames                          2.25
# Newham                                        2.24
# Havering                                      2.22
# Bexley                                        2.22
# ...

# %%
properties.shape
# Out:
# (45, 420)

# %%
print(properties.columns.dtype)
# Out:
# object

# %%
#In this second example the 12 month average for 2004 is comparted to the 2024 average

# %%
#Convert the column headers to a datetime
properties.columns = pd.to_datetime(properties.columns)

#Get the data type
print(properties.columns.dtype)
# Out:
# datetime64[ns]

# %%
# Get the yearly average for real estate prices
properties_yearly_average = properties.groupby(properties.columns.year, axis = 1).mean()

#Concatenate to the properties dataset
properties = pd.concat([properties, properties_yearly_average], axis=1)

properties.head()
# Out:
# /var/folders/gy/td7lhv614s93nmh2xjhqr0lm0000gn/T/ipykernel_33725/2586723151.py:2: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   properties_yearly_average = properties.groupby(properties.columns.year, axis = 1).mean()
# Unnamed: 0                NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# City of London      E09000001         91448.98487         82202.77314
# Barking & Dagenham  E09000002          50460.2266         51085.77983
# Barnet              E09000003         93284.51832         93190.16963
# Bexley              E09000004         64958.09036         64787.92069
# Brent               E09000005         71306.56698         72022.26197
#
# Unnamed: 0         1995-03-01 00:00:00 1995-04-01 00:00:00  \
# City of London             79120.70256         77101.20804
# Barking & Dagenham         51268.96956         53133.50526
# Barnet                     92247.52435         90762.87492
# ...

# %%
last_column_added_dtype = type(properties.columns[-1])
print(last_column_added_dtype)
# Out:
# <class 'float'>

# %%
properties.shape
# Out:
# (45, 420)

# %%
#Convert newly added column headers from a float to an int
properties.columns.values[-30:] = properties.columns.values[-30:].astype(int)

#Change settings for properties.head to display all the columns
pd.set_option('display.max_columns', None)

#Remove additional columns that do not belong
#properties.drop(properties.columns[-61:-31], axis=1, inplace=True)
#properties.drop(properties.columns[-31:-30], axis=1, inplace=True)

properties.head()
# Out:
# Unnamed: 0                NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# City of London      E09000001         91448.98487         82202.77314
# Barking & Dagenham  E09000002          50460.2266         51085.77983
# Barnet              E09000003         93284.51832         93190.16963
# Bexley              E09000004         64958.09036         64787.92069
# Brent               E09000005         71306.56698         72022.26197
#
# Unnamed: 0         1995-03-01 00:00:00 1995-04-01 00:00:00  \
# City of London             79120.70256         77101.20804
# Barking & Dagenham         51268.96956         53133.50526
# Barnet                     92247.52435         90762.87492
# Bexley                     64367.49344         64277.66881
# Brent                      72015.76274         72965.63094
#
# Unnamed: 0         1995-05-01 00:00:00 1995-06-01 00:00:00  \
# City of London             84409.14932         94900.51244
# Barking & Dagenham         53042.24852         53700.34831
# ...

# %%
properties.shape
# Out:
# (45, 389)

# %%
last_column_added_dtype = type(properties.columns[-1])

# %%
#Convert all data other than column headers and row headers into a float
properties = properties[-388:].apply(pd.to_numeric, errors='coerce')

print(properties.dtypes)
# Out:
# Unnamed: 0
# NaT                    float64
# 1995-01-01 00:00:00    float64
# 1995-02-01 00:00:00    float64
# 1995-03-01 00:00:00    float64
# 1995-04-01 00:00:00    float64
#                         ...
# 2020                   float64
# 2021                   float64
# 2022                   float64
# 2023                   float64
# 2024                   float64
# Length: 389, dtype: object

# %%
import matplotlib.dates as mdates

#Line plot of monthly price 
#properties.plot(x = "Unnamed: 0", y = "City of London")
#plt.show()
#row_1 = properties.loc[1]
#print(row_1)
#print(properties.columns)

# x_values1 are the column headers / column index selecting the last 240 column headers
x_values1 = properties.columns[-268:-32]

#convert x_values1 to datetime 
x_values1 = pd.to_datetime(x_values1)

# x_values2 are the column headers / column index selecting the last 20 column headers
x_values2 = properties.columns[-20:]

#convert x_values2 to a string then to a datetime
x_values2 = pd.to_datetime([str(year) + "-01-01" for year in x_values2])

# y_values1 selected are the 5th row and the last 240 values or last 20 years
y_values1 = properties.iloc[4][-268:-32]

# y_values2 selected are the 5th row and the last 20 values or last 20 years
y_values2 = properties.iloc[4][-20:]

#x_value_for_regressions = np.arange(1, len(x_values) + 1)
#regression_line = slope*x_value_for_regressions + intercept
#slope = np.polyfit(x_value_for_regressions, y_values, 1)

plt.plot(x_values1, y_values1, label='monthly data', color='gray')
plt.plot(x_values2, y_values2, label='Yearly Data', color='black', zorder=5)

plt.xlabel("Year")
plt.ylabel("Price in Pounds")
plt.title("Line Plot of Monthly Real Estate Price vs. Yearly Average for Brent Borough")
plt.legend()
           
#plt.plot(x_values, regression_line, color='red')

plt.show()

# %%
properties.shape
# Out:
# (45, 393)

# %%
# Identify the columns to delete
columns_to_delete = properties.columns[-4:]

# Drop the last 4 columns
properties = properties.drop(columns=columns_to_delete)

# %%
#In this third example a sum of least squares regression method is used to determine the 20 year change
import matplotlib.dates as mdates

#Line plot of monthly price 
#properties.plot(x = "Unnamed: 0", y = "City of London")
#plt.show()
#row_1 = properties.loc[1]
#print(row_1)
#print(properties.columns)

# x_values1 are the column headers / column index selecting the last 240 column headers
x_values1 = properties.columns[-268:-33]

#convert x_values1 to datetime 
x_values1 = pd.to_datetime(x_values1)

# x_values2 are the column headers / column index selecting the last 20 column headers
x_values2 = properties.columns[-20:]

#convert x_values2 to a string then to a datetime
x_values2 = pd.to_datetime([str(year) + "-01-01" for year in x_values2])

# y_values1 selected are the 5th row and the last 240 values or last 20 years
y_values1 = properties.iloc[4][-268:-33]

# y_values2 selected are the 5th row and the last 20 values or last 20 years
y_values2 = properties.iloc[4][-20:]

#x_value_for_regressions = np.arange(1, len(x_values) + 1)
#regression_line = slope*x_value_for_regressions + intercept
#slope = np.polyfit(x_value_for_regressions, y_values, 1)

plt.plot(x_values1, y_values1, label='monthly data', color='gray')
plt.plot(x_values2, y_values2, label='Yearly Data', color='black', zorder=5)

#convert x_values1 to numeric for linear regression
x_values1_numeric = mdates.date2num(x_values1)

# Perform the linear regression on monthly data
slope_monthly, intercept_monthly = np.polyfit(x_values1_numeric, y_values1, 1) 

# Generate the regression line for monthly data
regression_line_monthly = slope_monthly * x_values1_numeric + intercept_monthly

# Plot the regression line for monthly data
plt.plot(x_values1, regression_line_monthly, label='Monthly Regression Line', color='blue', linestyle='--')

plt.xlabel("Year")
plt.ylabel("Price in Pounds Sterling")
plt.title("Line Plot of Monthly Real Estate Price vs. Yearly Average for Brent Borough")
plt.legend()
           
#plt.plot(x_values, regression_line, color='red')

plt.show()

# %%
properties.head()
# Out:
# Unnamed: 0          NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# City of London      NaN          91448.98487          82202.77314
# Barking & Dagenham  NaN          50460.22660          51085.77983
# Barnet              NaN          93284.51832          93190.16963
# Bexley              NaN          64958.09036          64787.92069
# Brent               NaN          71306.56698          72022.26197
#
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00  \
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
# Brent                       72015.76274          72965.63094
#
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00  \
# City of London              84409.14932          94900.51244
# Barking & Dagenham          53042.24852          53700.34831
# ...

# %%
properties.shape
# Out:
# (45, 393)

# %%
#Convert all data other than column headers and row headers into a float
properties = properties[-389:].apply(pd.to_numeric, errors='coerce')

print(properties.dtypes)
# Out:
# Unnamed: 0
# NaT                                            float64
# 1995-01-01 00:00:00                            float64
# 1995-02-01 00:00:00                            float64
# 1995-03-01 00:00:00                            float64
# 1995-04-01 00:00:00                            float64
#                                                 ...
# 2024                                           float64
# 20_year_price_ratios                           float64
# 20_year_price_ratios_yearly_average            float64
# 20_year_price_ratios_rounded                   float64
# 20_year_price_ratios_yearly_average_rounded    float64
# Length: 393, dtype: object

# %%
properties.head()
# Out:
# Unnamed: 0          NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# City of London      NaN          91448.98487          82202.77314
# Barking & Dagenham  NaN          50460.22660          51085.77983
# Barnet              NaN          93284.51832          93190.16963
# Bexley              NaN          64958.09036          64787.92069
# Brent               NaN          71306.56698          72022.26197
#
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00  \
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
# Brent                       72015.76274          72965.63094
#
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00  \
# City of London              84409.14932          94900.51244
# Barking & Dagenham          53042.24852          53700.34831
# ...

# %%
properties.shape
# Out:
# (45, 393)

# %%
# Identify the columns to delete
columns_to_delete = properties.columns[-3:]

# Drop the last 3 columns
properties = properties.drop(columns=columns_to_delete)

# %%
properties.shape
# Out:
# (45, 390)

# %%
properties.head()
# Out:
# Unnamed: 0          NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# City of London      NaN          91448.98487          82202.77314
# Barking & Dagenham  NaN          50460.22660          51085.77983
# Barnet              NaN          93284.51832          93190.16963
# Bexley              NaN          64958.09036          64787.92069
# Brent               NaN          71306.56698          72022.26197
#
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00  \
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
# Brent                       72015.76274          72965.63094
#
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00  \
# City of London              84409.14932          94900.51244
# Barking & Dagenham          53042.24852          53700.34831
# ...

# %%
#In this final example I took the ratio of current house prices to prices 20 years ago by selecting the specific month
#I then take the ratio of current house prices to prices 20 yeas ago using the average for the year

# Ratio of current house prices to prices 20 years ago
properties['20_year_price_ratios'] = properties.iloc[0:, 356] / properties.iloc[0:, 116]

#Ratio of yearly averages of house prices in 2024 to yearly averages for 2004
properties['20_year_price_ratios_yearly_average'] = properties.iloc[0:, 388] / properties.iloc[0:, 368]

#Convert 20 year price ratios to numeric 
properties['20_year_price_ratios'] = pd.to_numeric(properties['20_year_price_ratios'], errors='coerce')

#Convert 20 year price ratios for yearly averages to numeric 
properties['20_year_price_ratios_yearly_average'] = pd.to_numeric(properties['20_year_price_ratios_yearly_average'], errors='coerce')

#Round to 2 decimal places
properties['20_year_price_ratios_rounded'] = properties['20_year_price_ratios'].round(2)

#Round to 2 decimal places
properties['20_year_price_ratios_yearly_average_rounded'] = properties['20_year_price_ratios_yearly_average'].round(2)

#properties['20_year_price_ratios_rounded'] = pd.to_numeric(properties['20_year_price_ratios_rounded'], errors='coerce')

#Sort in descending order
#properties_sorted = properties.sort_values(by='20_year_price_ratios_rounded', ascending=False)
#properties_sorted_yearly_averages = properties.sort_values(by='20_year_price_ratios_yearly_average_rounded', ascending=False)

#Sort according to properties_sorted_yearly_average

#Sort by 20_year_price_ratios_rounded
properties_sorted = properties.sort_values(by='20_year_price_ratios_yearly_average_rounded', ascending=False)

#Select the columns you want to display by passing them into properties_sorted
properties_sorted_displayed = properties_sorted[['20_year_price_ratios_rounded', '20_year_price_ratios_yearly_average_rounded']]


#print the 2 selected columns sorted
print(properties_sorted_displayed)

#Select and print the last column
#town_price_ratios = properties_sorted.iloc[: , -2:]
# Out:
# Unnamed: 0            20_year_price_ratios_rounded  \
# Hackney                                       2.61
# City of London                                2.47
# Westminster                                   2.54
# Waltham Forest                                2.53
# Kensington & Chelsea                          2.13
# Islington                                     2.31
# Lewisham                                      2.48
# Haringey                                      2.40
# Inner London                                  2.32
# Lambeth                                       2.32
# Merton                                        2.36
# Greenwich                                     2.41
# Camden                                        2.20
# Wandsworth                                    2.21
# Richmond upon Thames                          2.25
# LONDON                                        2.26
# Bexley                                        2.22
# ...

# %%
#properties.shape
#print(properties.head())
print(properties['20_year_price_ratios'].dtype)
# Out:
# float64

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#Conclusion
We determined which boroughs of London have seen the greatest average price increase over the last 20 years both based on monthly data and also based on yearly averages.
Average housing price data was downloaded from the London DataStore.
That data was then transposed and tidied up. 
Housing princes over time for one London Borough "Brent Borough" were visualized as a line plot for the monthly price, the yearly price (by taking the monthly average) and as a sum of least squares linear regression
Ratio of Current House Prices to Prices 20 years ago was calculated by creating a new column 20_year_price_ratios by dividing the column of the last housing price data points to the column containing the housing prices 240 months earlier or 20 years earlier
Ratio of Current House Prices to Prices 20 years ago was calculated by creating a new column 20_year_price_ratios_yearly_average by dividing the column of the last housing price data points to the column containing the housing prices 20 years earlier
That data was also sorted in descending order.

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!
